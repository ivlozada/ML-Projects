# %% [markdown]
# <a href="https://colab.research.google.com/github/ivlozada/ML-Projects/blob/main/Machine_Learning_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###################################################################################
# https://DEXSPORT.IO
# https://www.sportsbookreviewsonline.com/scoresoddsarchives/scoresoddsarchives.htm
###################################################################################

# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pwd
! ls -l
#! pip install colorama
! rm -rf ML-Projects
! rm -rf *
! git clone https://github.com/ivlozada/ML-Projects.git
! mv -v ML-Projects/* .
! #cp -rf /content/NBA-Machine-Learning-Sports-Betting/Tests/* /content/
! pip install -r requirements.txt

from IPython.display import clear_output
clear_output()

print("Successful Boostrap!!!")
# Out:
# Successful Boostrap!!!

# %%
#! python3 main.py -xgb -odds=fanduel
! python3 main.py -A -odds=fanduel
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# 2023-01-28 18:33:17.376939: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-28 18:33:17.377062: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e5b4c766fbf8): /proc/driver/nvidia/version does not exist
# 2023-01-28 18:33:17.377557: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# ------------------fanduel odds data------------------
# Denver Nuggets (164) @ Philadelphia 76ers (-196)
# New York Knicks (108) @ Brooklyn Nets (-126)
# Chicago Bulls (-138) @ Orlando Magic (118)
# Houston Rockets (142) @ Detroit Pistons (-168)
# LA Clippers (-112) @ Atlanta Hawks (-104)
# Sacramento Kings (-134) @ Minnesota Timberwolves (114)
# Washington Wizards (162) @ New Orleans Pelicans (-194)
# Phoenix Suns (-198) @ San Antonio Spurs (166)
# Los Angeles Lakers (300) @ Boston Celtics (-375)
# Dallas Mavericks (240) @ Utah Jazz (-295)
# Toronto Raptors (154) @ Portland Trail Blazers (-186)
# ---------------XGBoost Model Predictions---------------
# Philadelphia 76ers (59.7%) vs Denver Nuggets: UNDER 231.5 (65.5%)
# Brooklyn Nets (63.5%) vs New York Knicks: OVER 223 (63.5%)
# Orlando Magic vs Chicago Bulls (52.1%): UNDER 230.5 (65.0%)
# Detroit Pistons (58.0%) vs Houston Rockets: OVER 236.5 (61.4%)
# Atlanta Hawks (51.2%) vs LA Clippers: UNDER 232.5 (74.6%)
# Minnesota Timberwolves vs Sacramento Kings (58.7%): UNDER 237.5 (61.0%)
# New Orleans Pelicans (71.8%) vs Washington Wizards: UNDER 230 (50.6%)
# San Antonio Spurs vs Phoenix Suns (72.2%): UNDER 232 (53.8%)
# Boston Celtics (82.3%) vs Los Angeles Lakers: OVER 233.5 (58.0%)
openai.api_key = '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'

text = subprocess.run(["python3", "main.py", "-xgb", "-odds=fanduel"], capture_output=True).stdout.decode()
fanduel_odds_data = text.split("------------------fanduel odds data------------------")[1].split("---------------XGBoost Model Predictions---------------")[0].strip()
predictions = text.split("---------------XGBoost Model Predictions---------------")[1].split("--------------------Expected Value---------------------")[0].strip()
expected_value = text.split("--------------------Expected Value---------------------")[1].split("-------------------------------------------------------")[0]

# Extract winners and losers
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=(f"tell me the winners and losers and display indexes and numbers: {text}"),
    max_tokens=2000
)
# Print the summary
print("\n")
print(response["choices"][0]["text"])
print("\n")



# Twitter sentiment
import tweepy
from textblob import TextBlob

# Twitter API credentials
consumer_key = "kD85Wj14kFwnh8wA7jTt19wbT"
consumer_secret = "75bpu42dhkrtbAvyOLErteUH1HGHVUYNpoeD1jj6iTcMWFKdJk"
access_token = "1276931666900996096-vWto6ZfDVGtMUeOs2yVMojkUBujZOj"
access_token_secret = "HdcjGNFaJ7h02Hlb15qMS0zaBX7wKDX0YXdcRWZwhV6IQ"

# Authenticate with Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

import tweepy
from textblob import TextBlob

# Twitter API credentials
consumer_key = "kD85Wj14kFwnh8wA7jTt19wbT"
consumer_secret = "75bpu42dhkrtbAvyOLErteUH1HGHVUYNpoeD1jj6iTcMWFKdJk"
access_token = "1276931666900996096-vWto6ZfDVGtMUeOs2yVMojkUBujZOj"
access_token_secret = "HdcjGNFaJ7h02Hlb15qMS0zaBX7wKDX0YXdcRWZwhV6IQ"

# Authenticate with Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

winners_losers = response["choices"][0]["text"]

######################################
# Search for tweets about the Winners
######################################
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=(f"No dislay numbers, No display indexes, only display winners: {text}"),
    max_tokens=2000
)
winners_teams = ((response["choices"][0]["text"].split("Winners:"))[1]).split(",")

print("TWITTER SENTIMENT")

for team in winners_teams:
  print(team)
  winners_tweets = tweepy.Cursor(api.search, q=team).items(100)
  # Perform sentiment analysis on tweets
  positive_tweets = 0
  negative_tweets = 0
  neutral_tweets = 0

  for tweet in winners_tweets:
    analysis = TextBlob(tweet.text)
    if analysis.sentiment.polarity > 0:
      positive_tweets += 1
    elif analysis.sentiment.polarity < 0:
      negative_tweets += 1
    else:
      neutral_tweets += 1

  # Print results
  print("Positive tweets: ", positive_tweets)
  print("Negative tweets: ", negative_tweets)
  print("Neutral tweets: ", neutral_tweets, "\n")

print("Expected Value(EV):", expected_value)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openai in /usr/local/lib/python3.8/dist-packages (0.26.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.8/dist-packages (from openai) (2.25.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from openai) (3.8.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai) (4.59.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->openai) (4.0.2)
#
#
# Winners: Brooklyn Nets, New Orleans Pelicans, Phoenix Suns, Boston Celtics, Dallas Mavericks, Portland Trail Blazers
# Losers: New York Knicks, Chicago Bulls, Detroit Pistons, LA Clippers, Minnesota Timberwolves, Washington Wizards, San Antonio Spurs, Los Angeles Lakers, Utah Jazz, Toronto Raptors
# Indexes and Numbers:
#  Philadelphia 76ers: -3.92
#  Denver Nuggets: -4.05
#  Brooklyn Nets: 12.4
#  New York Knicks: -23.42
#  Orlando Magic: 4.47
#  Chicago Bulls: -10.18
#  Detroit Pistons: -7.4
#  Houston Rockets: 1.53
#  Atlanta Hawks: 0.52
#  LA Clippers: -7.72
#  Minnesota Timberwolves: -11.68
#  Sacramento Kings: 2.56
#  New Orleans Pelicans: 8.88
#  Washington Wizards: -26.23
#  San Antonio Spurs: -26.15
#  Phoenix Suns: 8.72
#  Boston Celtics: 2.58
#  Los Angeles Lakers: -25.54
#  Utah Jazz: -34.54
#  Dallas Mavericks: 75.61
#  Portland Trail Blazers: 2.04
#  Toronto Raptors: -14.55
#
#
# TWITTER SENTIMENT
#  Brooklyn Nets
# Positive tweets:  58
# Negative tweets:  5
# Neutral tweets:  37
#
#  Orlando Magic
# Positive tweets:  78
# Negative tweets:  5
# Neutral tweets:  17
#
#  Atlanta Hawks
# Positive tweets:  32
# Negative tweets:  14
# Neutral tweets:  54
#
#  Sacramento Kings
# Positive tweets:  41
# Negative tweets:  14
# Neutral tweets:  45
#
#  New Orleans Pelicans
# Positive tweets:  72
# Negative tweets:  11
# Neutral tweets:  17
#
#  Phoenix Suns
# Positive tweets:  31
# Negative tweets:  20
# Neutral tweets:  49
#
#  Boston Celtics
# Positive tweets:  27
# Negative tweets:  8
# Neutral tweets:  65
#
#  Dallas Mavericks
# Positive tweets:  37
# Negative tweets:  12
# Neutral tweets:  51
#
#  Portland Trail Blazers.
# Positive tweets:  32
# Negative tweets:  14
# Neutral tweets:  54
#
# Expected Value(EV):
# Philadelphia 76ers EV: -3.92
# Denver Nuggets EV: -4.05
# Brooklyn Nets EV: 12.4
# New York Knicks EV: -23.42
# Orlando Magic EV: 4.47
# Chicago Bulls EV: -10.18
# Detroit Pistons EV: -7.4
# Houston Rockets EV: 1.53
# Atlanta Hawks EV: 0.52
# LA Clippers EV: -7.72
# Minnesota Timberwolves EV: -11.68
# Sacramento Kings EV: 2.56
# New Orleans Pelicans EV: 8.88
# Washington Wizards EV: -26.23
# San Antonio Spurs EV: -26.15
# Phoenix Suns EV: 8.72
# Boston Celtics EV: 2.58
# Los Angeles Lakers EV: -25.54
# Utah Jazz EV: -34.54
# Dallas Mavericks EV: 75.61
# Portland Trail Blazers EV: 2.04
# Toronto Raptors EV: -14.55
